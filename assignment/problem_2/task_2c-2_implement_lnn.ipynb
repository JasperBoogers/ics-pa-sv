# %% [markdown]
# # RO47019: Intelligent Control Systems Practical Assignment
# * Period: 2022-2023, Q3
# * Course homepage: https://brightspace.tudelft.nl/d2l/home/500969
# * Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)
# * Teaching assistant: Ruben Martin Rodriguez (R.MartinRodriguez@student.tudelft.nl)
# * (c) TU Delft, 2023
#
# Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:

# %%
# Please fill in your names, student numbers, netID, and emails below.
STUDENT_1_NAME = "Jasper Boogers"
STUDENT_1_STUDENT_NUMBER = "4591704"
STUDENT_1_NETID = "jboogers"
STUDENT_1_EMAIL = "j.m.boogers@student.tudelft.nl"

# %%
# Note: this block is a check that you have filled in the above information.
# It will throw an AssertionError until all fields are filled
assert STUDENT_1_NAME != ""
assert STUDENT_1_STUDENT_NUMBER != ""
assert STUDENT_1_NETID != ""
assert STUDENT_1_EMAIL != ""

# %% [markdown]
# ### General announcements
#
# * Do *not* share your solutions, and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.
#
# * Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA.
#
# * There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.
#
# * This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook "uneditable" or "unremovable" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.
#
# * This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for youthat you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).

# %% [markdown]
# # Task 2c.2 - Implementation of a Lagrangian Neural Network (LNN) (9p)
#
# **Author:** Maximilian Stölzle (M.W.Stolzle@tudelft.nl)
#
# This notebook will guide you through the implementation of a Lagrangian neural network.

# %%
# Reloads the python files outside of this notebook automatically
# %load_ext autoreload
# %autoreload 2

# import all Python modules
from distutils.util import strtobool
from functools import partial
from jax.config import config as jax_config

jax_config.update("jax_platform_name", "cpu")  # set default device to 'cpu'
jax_config.update("jax_enable_x64", True)  # double precision
import jax
from jax import random
from jax import numpy as jnp
import os
from pathlib import Path

from jax_double_pendulum.integrators import rk4_step
from jax_double_pendulum.utils import normalize_link_angles

# define boolean to check if the notebook is run for the purposes of autograding
AUTOGRADING = strtobool(os.environ.get("AUTOGRADING", "false"))

# %% [markdown]
# ## Neural networks (2p)
#
# First, please finish the implementation of the neural networks `MassMatrixNN` and `PotentialEnergyNN`. Both neural networks should consist of four layers and have the following structure:
#
# 1. A linear layer mapping from the input dimension to the hidden state dimension $n_\mathrm{hidden}$.
#
# 2. A softplus activation function.
#
# 3. A linear layer with $n_\mathrm{hidden}$ as both the input and output dimension.
#
# 4. A softplus activation function.
#
# 5. A linear layer with $n_\mathrm{hidden}$ as both the input and output dimension.
#
# 6. A softplus activation function.
#
# 7. A linear layer with $n_\mathrm{hidden}$ as both the input and output dimension.
#
# 8. A softplus activation function.
#
# 9. A linear layer mapping from $n_\mathrm{hidden}$ to the output dimension.
#
#
# The hidden state dimension is set by the `num_hidden` attribute of the class to $32$. The softplus activation function is.a smooth approximation of the Rectified Linear Unit (ReLU) function.
#
# The mass matrix $M$ (sometimes also denoted as $B$) of mechanical systems has two important characteristics, which we want to enforce for our learned mass matrix as well:
#
# - The diagonal values are always positive
# - The matrix is symmetric
#
# The symmetry is given automatically by the fact that we only learn a triangular matrix and then derive the complete mass matrix from that triangular matrix. We can induce the first characteristic by applying a softplus activation function in conjunction with a shifting of the diagonals.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import MassMatrixNN and PotentialEnergyNN from lnn.ipynb
from ipynb.fs.full.lnn import MassMatrixNN, PotentialEnergyNN

# initialize the PRNG key at seed 0
_rng = random.PRNGKey(seed=0)

# initialize parameters of MassMatrixNN by passing a dummy input of ones through the network
_mass_matrix_nn_params = MassMatrixNN().init(_rng, jnp.ones((2,)))["params"]

# initialize parameters of PotentialEnergyNN by passing a dummy input of ones through the network
_potential_energy_nn_params = PotentialEnergyNN().init(_rng, jnp.ones((2,)))["params"]

# some dummy system state
_th = 0 * jnp.ones((2,))
_th_d = jnp.pi * jnp.ones((2,))

_M_nn = MassMatrixNN().apply({"params": _mass_matrix_nn_params}, _th)
_U = PotentialEnergyNN().apply({"params": _potential_energy_nn_params}, _th)

print("Computed mass matrix (output from neural network):\n", _M_nn)
print("Computed potential energy:\n", _U)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(
# Computed mass matrix (output from neural network):
#  [[ 0.54595144 -0.53372961]
#  [-0.53372961  0.97476694]]
# Computed potential energy:
#  [-0.30615477]

# %% [markdown]
# ## Lagrangian (1p)
#
# First, please implement the two functions `kinetic_energy_fn` and `potential_energy_fn` which compute the (estimated) kinetic energy and potential energy of the system respectively:
#
# \begin{equation}
#     \mathcal{T} = \frac{1}{2} \: \dot{\theta}^\mathrm{T} \: f_\mathrm{M}(\theta, \pi_\mathrm{M}) \: \dot{\theta},
#     \qquad
#     \mathcal{U} = f_\mathcal{U}(\theta, \pi_\mathcal{U}),
# \end{equation}
#
# where $f_\mathrm{M}(\theta, \pi_\mathrm{M})$ and $f_\mathcal{U}(\theta, \pi_\mathcal{U})$ are the two neural network forward functions respectively.
#
# The Lagrangian $\mathcal{L}$ is then defined as
#
# \begin{equation}
#     \mathcal{L} = \mathcal{T} - \mathcal{U},
# \end{equation}
#
# and needs to be implemented into `lagrangian_fn`.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import lagrangian_fn from lnn.ipynb
from ipynb.fs.full.lnn import lagrangian_fn

_L = lagrangian_fn(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _th,
    _th_d,
)
print("Computed Lagrangian:", _L)
# Out:
# ---------------------------------------------------------------------------
# ScopeCollectionNotFound                   Traceback (most recent call last)
# Cell In[5], line 6
#       1 # DO NOT REMOVE OR MODIFY THIS CELL
#       2
#       3 # import lagrangian_fn from lnn.ipynb
#       4 from ipynb.fs.full.lnn import lagrangian_fn
# ----> 6 _L = lagrangian_fn(
#       7     _mass_matrix_nn_params,
#       8     _potential_energy_nn_params,
#       9     _th,
#      10     _th_d,
#      11 )
#      12 print("Computed Lagrangian:", _L)
#
#     [... skipping hidden 12 frame]
#
# File /workspaces/ics-pa-sv/assignment/problem_2/lnn.ipynb:239, in lagrangian_fn(mass_matrix_nn_params, potential_energy_nn_params, th, th_d)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "ac408b5e",
#       6    "metadata": {
#       7     "deletable": false,
#       8     "editable": false,
#       9     "nbgrader": {
#      10      "cell_type": "markdown",
#      11      "checksum": "a96d02d6346fa7399cf6da0111ce0937",
#      12      "grade": false,
#      13      "grade_id": "cell-b00828259c8e42e8",
#      14      "locked": true,
#      15      "schema_version": 3,
#      16      "solution": false,
#      17      "task": false
#      18     }
#      19    },
#      20    "source": [
#      21     "# RO47019: Intelligent Control Systems Practical Assignment\n",
#      22     "* Period: 2022-2023, Q3\n",
#      23     "* Course homepage: https://brightspace.tudelft.nl/d2l/home/500969\n",
#      24     "* Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)\n",
#      25     "* Teaching assistant: Ruben Martin Rodriguez (R.MartinRodriguez@student.tudelft.nl)\n",
#      26     "* (c) TU Delft, 2023\n",
#      27     "\n",
#      28     "Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:"
#      29    ]
#      30   },
#      31   {
#      32    "cell_type": "code",
#      33    "execution_count": null,
#      34    "id": "4f9e220c",
#      35    "metadata": {},
#      36    "outputs": [],
#      37    "source": [
#      38     "# Please fill in your names, student numbers, netID, and emails below.\n",
#      39     "STUDENT_1_NAME = \"Jasper Boogers\"\n",
#      40     "STUDENT_1_STUDENT_NUMBER = \"4591704\"\n",
#      41     "STUDENT_1_NETID = \"jboogers\"\n",
#      42     "STUDENT_1_EMAIL = \"j.m.boogers@student.tudelft.nl\""
#      43    ]
#      44   },
#      45   {
#      46    "cell_type": "code",
#      47    "execution_count": null,
#      48    "id": "8ba32571",
#      49    "metadata": {
#      50     "deletable": false,
#      51     "editable": false,
#      52     "nbgrader": {
#      53      "cell_type": "code",
#      54      "checksum": "042927213b84aa368aa3ea72caa4cb60",
#      55      "grade": true,
#      56      "grade_id": "cell-9f148ec62e0de49c",
#      57      "locked": true,
#      58      "points": 0,
#      59      "schema_version": 3,
#      60      "solution": false,
#      61      "task": false
#      62     }
#      63    },
#      64    "outputs": [],
#      65    "source": [
#      66     "# Note: this block is a check that you have filled in the above information.\n",
#      67     "# It will throw an AssertionError until all fields are filled\n",
#      68     "assert STUDENT_1_NAME != \"\"\n",
#      69     "assert STUDENT_1_STUDENT_NUMBER != \"\"\n",
#      70     "assert STUDENT_1_NETID != \"\"\n",
#      71     "assert STUDENT_1_EMAIL != \"\""
#      72    ]
#      73   },
#      74   {
#      75    "cell_type": "markdown",
#      76    "id": "af317a94",
#      77    "metadata": {
#      78     "deletable": false,
#      79     "editable": false,
#      80     "nbgrader": {
#      81      "cell_type": "markdown",
#      82      "checksum": "e76ef40fcc3f08a0484661497162a1a9",
#      83      "grade": false,
#      84      "grade_id": "cell-4ea391677951116c",
#      85      "locked": true,
#      86      "schema_version": 3,
#      87      "solution": false,
#      88      "task": false
#      89     }
#      90    },
#      91    "source": [
#      92     "### General announcements\n",
#      93     "\n",
#      94     "* Do *not* share your solutions, and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.\n",
#      95     "\n",
#      96     "* Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA.\n",
#      97     "\n",
#      98     "* There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.\n",
#      99     "\n",
#     100     "* This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook \"uneditable\" or \"unremovable\" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.\n",
#     101     "\n",
#     102     "* This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for youthat you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.\n",
#     103     "\n",
#     104     "Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\\rightarrow$Run All)."
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "code",
#     109    "execution_count": null,
#     110    "id": "3c956945",
#     111    "metadata": {},
#     112    "outputs": [],
#     113    "source": []
#     114   },
#     115   {
#     116    "cell_type": "markdown",
#     117    "id": "387d2c60",
#     118    "metadata": {
#     119     "deletable": false,
#     120     "editable": false,
#     121     "nbgrader": {
#     122      "cell_type": "markdown",
#     123      "checksum": "800a1848822df3ce5559209f09cb2494",
#     124      "grade": false,
#     125      "grade_id": "cell-ed88010142fb94bb",
#     126      "locked": true,
#     127      "schema_version": 3,
#     128      "solution": false,
#     129      "task": false
#     130     }
#     131    },
#     132    "source": [
#     133     "# Lagrangian Neural Network (LNN)\n",
#     134     "\n",
#     135     "**Author:** Maximilian Stölzle (M.W.Stolzle@tudelft.nl)\n",
#     136     "\n",
#     137     "This notebook will contain functions implement a Lagrangian neural network. Please follow the notebook `task_2c-2_lnn_implementation.ipynb`, which guides you through these implementations."
#     138    ]
#     139   },
#     140   {
#     141    "cell_type": "code",
#     142    "execution_count": 2,
#     143    "id": "c5a29eaa",
#     144    "metadata": {
#     145     "deletable": false,
#     146     "editable": false,
#     147     "nbgrader": {
#     148      "cell_type": "code",
#     149      "checksum": "a303d00318410d3b1621fc2d60bd9064",
#     150      "grade": false,
#     151      "grade_id": "cell-6d73deac900e51cb",
#     152      "locked": true,
#     153      "schema_version": 3,
#     154      "solution": false,
#     155      "task": false
#     156     }
#     157    },
#     158    "outputs": [],
#     159    "source": [
#     160     "from flax import linen as nn\n",
#     161     "from flax.core import FrozenDict\n",
#     162     "from functools import partial\n",
#     163     "from jax.config import config as jax_config\n",
#     164     "\n",
#     165     "jax_config.update(\"jax_platform_name\", \"cpu\")  # set default device to 'cpu'\n",
#     166     "jax_config.update(\"jax_enable_x64\", True)  # double precision\n",
#     167     "import jax\n",
#     168     "from jax import jit, debug\n",
#     169     "import jax.numpy as jnp\n",
#     170     "import numpy as np\n",
#     171     "from typing import Dict, Tuple\n",
#     172     "\n",
#     173     "from jax_double_pendulum.integrators import rk4_step\n",
#     174     "from jax_double_pendulum.utils import normalize_link_angles"
#     175    ]
#     176   },
#     177   {
#     178    "cell_type": "code",
#     179    "execution_count": null,
#     180    "id": "f23c573c",
#     181    "metadata": {
#     182     "deletable": false,
#     183     "nbgrader": {
#     184      "cell_type": "code",
#     185      "checksum": "e709fa40e5ce83f6c5c71bbe2754665d",
#     186      "grade": false,
#     187      "grade_id": "cell-90677efa4e583357",
#     188      "locked": false,
#     189      "schema_version": 3,
#     190      "solution": true,
#     191      "task": false
#     192     }
#     193    },
#     194    "outputs": [],
#     195    "source": [
#     196     "class MassMatrixNN(nn.Module):\n",
#     197     "    \"\"\"\n",
#     198     "    Neural network to approximate the mass matrix.\n",
#     199     "    \"\"\"\n",
#     200     "\n",
#     201     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     202     "\n",
#     203     "    diagonal_shift = 0.001  # shifting the diagonal before activation function\n",
#     204     "    diagonal_eps = 0.002  # small value added to the resulting diagonal\n",
#     205     "\n",
#     206     "    @nn.compact\n",
#     207     "    def __call__(self, th: jnp.ndarray) -> jnp.ndarray:\n",
#     208     "        \"\"\"\n",
#     209     "        Evaluate the mass matrix for the current neural network parameters\n",
#     210     "        Args:\n",
#     211     "            th: link angles of shape (2, ).\n",
#     212     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     213     "        Returns:\n",
#     214     "            M: mass matrix of shape (2, 2)\n",
#     215     "        \"\"\"\n",
#     216     "        num_dof = th.shape[-1]  # Degrees of Freedom of the robot\n",
#     217     "        num_nn_outputs = int((num_dof**2 + num_dof) / 2)\n",
#     218     "\n",
#     219     "        # implement the neural network layers\n",
#     220     "        # use nn.Dense and nn.softplus layers\n",
#     221     "        # the output of the last layer needs to be saved in the variable `m`\n",
#     222     "        # the elements of the triangular matrix are the outputs of the network\n",
#     223     "        m = nn.Dense(features=self.num_hidden)(th)\n",
#     224     "        m = nn.softplus(m)\n",
#     225     "        m = nn.Dense(features=self.num_hidden)(m)\n",
#     226     "        m = nn.softplus(m)\n",
#     227     "        m = nn.Dense(features=self.num_hidden)(m)\n",
#     228     "        m = nn.softplus(m)\n",
#     229     "        m = nn.Dense(features=self.num_hidden)(m)\n",
#     230     "        m = nn.softplus(m)\n",
#     231     "        m = nn.Dense(features=num_nn_outputs)(m)\n",
#     232     "\n",
#     233     "        # split-off the first num_dof as the diagonal entries\n",
#     234     "        l_diagonal, l_off_diagonal = jnp.split(\n",
#     235     "            m,\n",
#     236     "            np.array(\n",
#     237     "                [\n",
#     238     "                    num_dof,\n",
# --> 239     "                ]\n",
#     240     "            ),\n",
#     241     "            axis=-1,\n",
#     242     "        )\n",
#     243     "\n",
#     244     "        # ensure positive diagonal\n",
#     245     "        # first, add `self.diagonal_shift` to the diagonal\n",
#     246     "        # then, apply softplus\n",
#     247     "        # finally, add `self.diagonal_eps` to the diagonal\n",
#     248     "        # YOUR CODE HERE\n",
#     249     "        l_diagonal = l_diagonal.at[:].set(l_diagonal+self.diagonal_shift)\n",
#     250     "        l_diagonal = nn.softplus(l_diagonal)\n",
#     251     "        l_diagonal = l_diagonal.at[:].set(l_diagonal+self.diagonal_eps)\n",
#     252     "\n",
#     253     "        # Calculate the indices of the diagonal elements of L:\n",
#     254     "        indices_diag = np.arange(num_dof, dtype=int) + 1\n",
#     255     "        indices_diag = (indices_diag * (indices_diag + 1) / 2 - 1).astype(int)  # [0, 2]\n",
#     256     "        # Calculate the indices of the off-diagonal elements of L:\n",
#     257     "        indices_off_diag = np.setdiff1d(np.arange(num_nn_outputs), indices_diag)  # [1]\n",
#     258     "        # Indexing for concatenation of l_diagonal and l_off_diagonal\n",
#     259     "        indices_nn_output = np.hstack((indices_diag, indices_off_diag))  # [0, 2, 1]\n",
#     260     "\n",
#     261     "        # vector of lower triangular matrix (i.e. flattened lower triangular matrix)\n",
#     262     "        vec_tril = jnp.concatenate([l_diagonal, l_off_diagonal], axis=-1)[\n",
#     263     "            ..., indices_nn_output\n",
#     264     "        ]\n",
#     265     "\n",
#     266     "        # construct empty triangular matrix\n",
#     267     "        tril_mat = jnp.zeros((num_dof, num_dof))\n",
#     268     "        # (i, j) indices of lower triangular matrix\n",
#     269     "        indices_tril = np.tril_indices(num_dof)  # (array([0, 1, 1]), array([0, 0, 1]))\n",
#     270     "        # populate triangular matrix from vector\n",
#     271     "        tril_mat = tril_mat.at[indices_tril].set(vec_tril[:])\n",
#     272     "\n",
#     273     "        # construct mass matrix from triangular matrix\n",
#     274     "        M = tril_mat @ tril_mat.transpose()\n",
#     275     "\n",
#     276     "        return M"
#     277    ]
#     278   },
#     279   {
#     280    "cell_type": "code",
#     281    "execution_count": null,
#     282    "id": "a6974402",
#     283    "metadata": {
#     284     "deletable": false,
#     285     "nbgrader": {
#     286      "cell_type": "code",
#     287      "checksum": "54d2a75f25cd3fc260bc1c2a7370fdfc",
#     288      "grade": false,
#     289      "grade_id": "cell-e2583bbbc2ae1715",
#     290      "locked": false,
#     291      "schema_version": 3,
#     292      "solution": true,
#     293      "task": false
#     294     }
#     295    },
#     296    "outputs": [],
#     297    "source": [
#     298     "class PotentialEnergyNN(nn.Module):\n",
#     299     "    \"\"\"\n",
#     300     "    Neural network to approximate the potential energy.\n",
#     301     "    \"\"\"\n",
#     302     "\n",
#     303     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     304     "\n",
#     305     "    @nn.compact\n",
#     306     "    def __call__(self, th: jnp.ndarray) -> jnp.ndarray:\n",
#     307     "        \"\"\"\n",
#     308     "        Evaluate the potential energy for the current neural network parameters\n",
#     309     "        Args:\n",
#     310     "            th: link angles of shape (2, ).\n",
#     311     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     312     "        Returns:\n",
#     313     "            U: potential energy of shape ( )\n",
#     314     "        \"\"\"\n",
#     315     "\n",
#     316     "        U = nn.Dense(features=self.num_hidden)(th)\n",
#     317     "        U = nn.softplus(U)\n",
#     318     "        U = nn.Dense(features=self.num_hidden)(U)\n",
#     319     "        U = nn.softplus(U)\n",
#     320     "        U = nn.Dense(features=self.num_hidden)(U)\n",
#     321     "        U = nn.softplus(U)\n",
#     322     "        U = nn.Dense(features=self.num_hidden)(U)\n",
#     323     "        U = nn.softplus(U)\n",
#     324     "        U = nn.Dense(features=1)(U)\n",
#     325     "        return U"
#     326    ]
#     327   },
#     328   {
#     329    "cell_type": "code",
#     330    "execution_count": null,
#     331    "id": "2f406274",
#     332    "metadata": {
#     333     "deletable": false,
#     334     "nbgrader": {
#     335      "cell_type": "code",
#     336      "checksum": "b4f4bc19063941c7226631495da210c5",
#     337      "grade": false,
#     338      "grade_id": "cell-a63dfc33b5289c23",
#     339      "locked": false,
#     340      "schema_version": 3,
#     341      "solution": true,
#     342      "task": false
#     343     }
#     344    },
#     345    "outputs": [],
#     346    "source": [
#     347     "@jit\n",
#     348     "def kinetic_energy_fn(\n",
#     349     "    mass_matrix_nn_params: Dict, th: jnp.ndarray, th_d: jnp.ndarray\n",
#     350     ") -> jnp.ndarray:\n",
#     351     "    \"\"\"\n",
#     352     "    Compute the kinetic energy of the system using a learned neural-network-based mass matrix\n",
#     353     "    Args:\n",
#     354     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     355     "        th: link angles of shape (2, ).\n",
#     356     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     357     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     358     "    Returns:\n",
#     359     "        T: kinetic energy of shape ( )\n",
#     360     "    \"\"\"\n",
#     361     "    # evaluate mass matrix at current system state\n",
#     362     "    M = MassMatrixNN().apply(mass_matrix_nn_params, th)\n",
#     363     "\n",
#     364     "    # compute kinetic energy\n",
#     365     "    T = 0.5*th_d.transpose()@M@th_d\n",
#     366     "\n",
#     367     "    return T"
#     368    ]
#     369   },
#     370   {
#     371    "cell_type": "code",
#     372    "execution_count": null,
#     373    "id": "09e7875a",
#     374    "metadata": {
#     375     "deletable": false,
#     376     "nbgrader": {
#     377      "cell_type": "code",
#     378      "checksum": "6c2fa7ba4d25a8bf0165658284855273",
#     379      "grade": false,
#     380      "grade_id": "cell-6a3a2cc1abe3951d",
#     381      "locked": false,
#     382      "schema_version": 3,
#     383      "solution": true,
#     384      "task": false
#     385     }
#     386    },
#     387    "outputs": [],
#     388    "source": [
#     389     "@jit\n",
#     390     "def potential_energy_fn(\n",
#     391     "    potential_energy_nn_params: FrozenDict, th: jnp.ndarray\n",
#     392     ") -> jnp.ndarray:\n",
#     393     "    \"\"\"\n",
#     394     "    Compute the potential energy of the system using the `PotentialEnergyNN` neural network\n",
#     395     "    Args:\n",
#     396     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     397     "        th: link angles of shape (2, ).\n",
#     398     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     399     "    Returns:\n",
#     400     "        U: potential energy of shape ( )\n",
#     401     "    \"\"\"\n",
#     402     "    # evaluate the `PotentialEnergyNN` at current system state\n",
#     403     "    U = PotentialEnergyNN().apply(potential_energy_nn_params, th)\n",
#     404     "\n",
#     405     "    return U.squeeze()"
#     406    ]
#     407   },
#     408   {
#     409    "cell_type": "code",
#     410    "execution_count": null,
#     411    "id": "6126ac5a",
#     412    "metadata": {
#     413     "deletable": false,
#     414     "nbgrader": {
#     415      "cell_type": "code",
#     416      "checksum": "e5cf488189981146c3cc1464eaf904ef",
#     417      "grade": false,
#     418      "grade_id": "cell-216db944065f69db",
#     419      "locked": false,
#     420      "schema_version": 3,
#     421      "solution": true,
#     422      "task": false
#     423     }
#     424    },
#     425    "outputs": [],
#     426    "source": [
#     427     "@jit\n",
#     428     "def lagrangian_fn(\n",
#     429     "    mass_matrix_nn_params: FrozenDict,\n",
#     430     "    potential_energy_nn_params: FrozenDict,\n",
#     431     "    th: jnp.ndarray,\n",
#     432     "    th_d: jnp.ndarray,\n",
#     433     ") -> jnp.ndarray:\n",
#     434     "    \"\"\"\n",
#     435     "    Compute the Lagrangian of the system using a learned neural-network-based mass matrix and potential energy\n",
#     436     "    Args:\n",
#     437     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     438     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     439     "        th: link angles of shape (2, ).\n",
#     440     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     441     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     442     "    Returns:\n",
#     443     "        L: Lagrangian of shape ( )\n",
#     444     "    \"\"\"\n",
#     445     "    # Compute the Lagrangian\n",
#     446     "    T = kinetic_energy_fn(mass_matrix_nn_params, th, th_d)\n",
#     447     "    U = potential_energy_fn(potential_energy_nn_params, th)\n",
#     448     "\n",
#     449     "    return T-U"
#     450    ]
#     451   },
#     452   {
#     453    "cell_type": "code",
#     454    "execution_count": null,
#     455    "id": "6b4ced74",
#     456    "metadata": {
#     457     "deletable": false,
#     458     "nbgrader": {
#     459      "cell_type": "code",
#     460      "checksum": "f16ac3536395e5a99f76df9fe88d2ef1",
#     461      "grade": false,
#     462      "grade_id": "cell-82a33f0bd7f4ddcc",
#     463      "locked": false,
#     464      "schema_version": 3,
#     465      "solution": true,
#     466      "task": false
#     467     }
#     468    },
#     469    "outputs": [],
#     470    "source": [
#     471     "@jit\n",
#     472     "def dynamical_matrices(\n",
#     473     "    mass_matrix_nn_params: FrozenDict,\n",
#     474     "    potential_energy_nn_params: FrozenDict,\n",
#     475     "    th: jnp.ndarray,\n",
#     476     "    th_d: jnp.ndarray,\n",
#     477     ") -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray]:\n",
#     478     "    \"\"\"\n",
#     479     "    Compute the dynamical matrices of the system using a learned neural-network-based\n",
#     480     "    mass matrix and potential energy\n",
#     481     "    The resulting Equations of Motion (EoM) are given by:\n",
#     482     "        M @ th_dd + C @ th_d + G = tau\n",
#     483     "    where tau are the external torques applied on the links.\n",
#     484     "\n",
#     485     "    Args:\n",
#     486     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     487     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     488     "        th: link angles of double pendulum of shape (2, )\n",
#     489     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     490     "\n",
#     491     "    Returns:\n",
#     492     "        M: mass matrix of shape (2, 2)\n",
#     493     "        C: coriolis and centrifugal matrix of shape (2, 2)\n",
#     494     "        G: gravity matrix of shape (2, )\n",
#     495     "    \"\"\"\n",
#     496     "    # the neural network needs to be robust to the redundancy of th = th + n * 2*pi\n",
#     497     "    # therefore, we first project the given link angles onto the interval [-pi, pi]\n",
#     498     "    # Hint: use the `jax_double_pendulum.utils.normalize_link_angles` function.\n",
#     499     "    # Hint: use `jax.grad` or `jax.value_and_grad` for the 1st-order partial derivatives\n",
#     500     "    # Hint: use the `jax.hessian` function for computing the 2nd-order partial derivatives.\n",
#     501     "    # YOUR CODE HERE\n",
#     502     "    th = normalize_link_angles(th)\n",
#     503     "\n",
#     504     "    # Compute the dynamical matrices by taking the appropiate partial derivatives of the Lagrangian\n",
#     505     "    \n",
#     506     "    # M, C, G = jnp.zeros((2, 2)), jnp.zeros((2, 2)), jnp.zeros((2,))\n",
#     507     "    # # YOUR CODE HERE\n",
#     508     "    # raise NotImplementedError()\n",
#     509     "\n",
#     510     "    lag = partial(lagrangian_fn, mass_matrix_nn_params, potential_energy_nn_params)\n",
#     511     "    _, (C, M) = jax.hessian(lag,(0,1))(th, th_d)\n",
#     512     "    G = jax.grad(lag, 0)(th, th_d)\n",
#     513     "    return M, C, -G"
#     514    ]
#     515   },
#     516   {
#     517    "cell_type": "code",
#     518    "execution_count": null,
#     519    "id": "05b32d77",
#     520    "metadata": {
#     521     "deletable": false,
#     522     "nbgrader": {
#     523      "cell_type": "code",
#     524      "checksum": "d976761dc16911853cf1cacfdc81d533",
#     525      "grade": false,
#     526      "grade_id": "cell-2538b9eeb0fe06f9",
#     527      "locked": false,
#     528      "schema_version": 3,
#     529      "solution": true,
#     530      "task": false
#     531     }
#     532    },
#     533    "outputs": [],
#     534    "source": [
#     535     "@jit\n",
#     536     "def continuous_forward_dynamics(\n",
#     537     "    mass_matrix_nn_params: FrozenDict,\n",
#     538     "    potential_energy_nn_params: FrozenDict,\n",
#     539     "    th: jnp.ndarray,\n",
#     540     "    th_d: jnp.ndarray,\n",
#     541     "    tau: jnp.ndarray = jnp.zeros((2,)),\n",
#     542     ") -> jnp.ndarray:\n",
#     543     "    \"\"\"\n",
#     544     "    Compute the continuous forward dynamics of the system using a learned neural-network-based\n",
#     545     "    mass matrix and potential energy\n",
#     546     "    Args:\n",
#     547     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     548     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     549     "        th: link angles of double pendulum of shape (2, )\n",
#     550     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     551     "        tau: link torques of double pendulum of shape (2, )\n",
#     552     "    Returns:\n",
#     553     "        th_dd: link angular accelerations of double pendulum of shape (2, )\n",
#     554     "    \"\"\"\n",
#     555     "    # Compute the angular acceleration of the links\n",
#     556     "    th_dd = jnp.zeros((2,))\n",
#     557     "    # YOUR CODE HERE\n",
#     558     "    M, C, G = dynamical_matrices(mass_matrix_nn_params,\n",
#     559     "                                potential_energy_nn_params,\n",
#     560     "                                th,\n",
#     561     "                                th_d)\n",
#     562     "    th_dd = jnp.linalg.inv(M) @ (tau - C @ th_d - G)\n",
#     563     "\n",
#     564     "    return th_dd"
#     565    ]
#     566   },
#     567   {
#     568    "cell_type": "code",
#     569    "execution_count": null,
#     570    "id": "c6819b64",
#     571    "metadata": {
#     572     "deletable": false,
#     573     "nbgrader": {
#     574      "cell_type": "code",
#     575      "checksum": "e00d6698af6c0747d29a5de335b9d088",
#     576      "grade": false,
#     577      "grade_id": "cell-04d5fab5a1e9a1e6",
#     578      "locked": false,
#     579      "schema_version": 3,
#     580      "solution": true,
#     581      "task": false
#     582     }
#     583    },
#     584    "outputs": [],
#     585    "source": [
#     586     "def continuous_state_space_dynamics(\n",
#     587     "    mass_matrix_nn_params: FrozenDict,\n",
#     588     "    potential_energy_nn_params: FrozenDict,\n",
#     589     "    x: jnp.ndarray,\n",
#     590     "    tau: jnp.ndarray,\n",
#     591     ") -> Tuple[jnp.ndarray, jnp.ndarray]:\n",
#     592     "    \"\"\"\n",
#     593     "    Compute the continuous forward dynamics of the system in state-space representation\n",
#     594     "    using the Lagrangian neural network\n",
#     595     "    Args:\n",
#     596     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     597     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     598     "        x: system state of shape (4, ) consisting of the link angles and velocities\n",
#     599     "        tau: link torques of shape (2, )\n",
#     600     "    Returns:\n",
#     601     "        dx_dt: time derivative of the system state of shape (4, )\n",
#     602     "        y: system output of shape (2, ) consisting of the link angles\n",
#     603     "    \"\"\"\n",
#     604     "    # YOUR CODE HERE\n",
#     605     "    th, th_d = jnp.split(x, 2)\n",
#     606     "    th_dd = continuous_forward_dynamics(mass_matrix_nn_params, potential_energy_nn_params, th, th_d, tau)\n",
#     607     "\n",
#     608     "    dx_dt = jnp.concatenate([th_d, th_dd])\n",
#     609     "    y = th\n",
#     610     "    return dx_dt, y"
#     611    ]
#     612   },
#     613   {
#     614    "cell_type": "code",
#     615    "execution_count": null,
#     616    "id": "92563f5d",
#     617    "metadata": {
#     618     "deletable": false,
#     619     "nbgrader": {
#     620      "cell_type": "code",
#     621      "checksum": "0d5de7eb08c349b525f028391bfdcf32",
#     622      "grade": false,
#     623      "grade_id": "cell-9290e00886679359",
#     624      "locked": false,
#     625      "schema_version": 3,
#     626      "solution": true,
#     627      "task": false
#     628     }
#     629    },
#     630    "outputs": [],
#     631    "source": [
#     632     "@jit\n",
#     633     "def discrete_forward_dynamics(\n",
#     634     "    mass_matrix_nn_params: FrozenDict,\n",
#     635     "    potential_energy_nn_params: FrozenDict,\n",
#     636     "    dt: jnp.ndarray,\n",
#     637     "    th_curr: jnp.ndarray,\n",
#     638     "    th_d_curr: jnp.ndarray,\n",
#     639     "    tau: jnp.ndarray = jnp.zeros((2,)),\n",
#     640     ") -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray]:\n",
#     641     "    \"\"\"\n",
#     642     "    Compute the discrete forward dynamics of the system using a learned neural-network-based\n",
#     643     "    mass matrix and potential energy\n",
#     644     "    Args:\n",
#     645     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     646     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     647     "        dt: time step between the current and the next state [s] of shape ( )\n",
#     648     "        th_curr: current link angles of double pendulum of shape (2, )\n",
#     649     "        th_d_curr: current link angular velocities of double pendulum of shape (2, )\n",
#     650     "        tau: link torques of double pendulum of shape (2, )\n",
#     651     "    Returns:\n",
#     652     "        th_next: link angles at the next time step of double pendulum of shape (2, )\n",
#     653     "        th_d_next: link angular velocities at the next time step of double pendulum of shape (2, )\n",
#     654     "        th_dd: link angular accelerations between current and next time step of double pendulum of shape (2, )\n",
#     655     "    \"\"\"\n",
#     656     "    # YOUR CODE HERE\n",
#     657     "    th_dd = continuous_forward_dynamics(mass_matrix_nn_params, potential_energy_nn_params, th_curr, th_d_curr, tau)\n",
#     658     "    x_next = rk4_step(\n",
#     659     "        ode_fun= lambda _x: partial(continuous_state_space_dynamics,\n",
#     660     "                                    mass_matrix_nn_params,\n",
#     661     "                                    potential_energy_nn_params,\n",
#     662     "                                    tau=tau)(_x)[0],\n",
#     663     "        x=jnp.concatenate([th_curr, th_d_curr]),\n",
#     664     "        dt=dt\n",
#     665     "    )\n",
#     666     "\n",
#     667     "    th_next, th_d_next = jnp.split(x_next, 2)\n",
#     668     "\n",
#     669     "    return th_next, th_d_next, th_dd"
#     670    ]
#     671   },
#     672   {
#     673    "cell_type": "code",
#     674    "execution_count": null,
#     675    "id": "7cdbdacd",
#     676    "metadata": {},
#     677    "outputs": [],
#     678    "source": []
#     679   }
#     680  ],
#     681  "metadata": {
#     682   "kernelspec": {
#     683    "display_name": "Python 3 (ipykernel)",
#     684    "language": "python",
#     685    "name": "python3"
#     686   },
#     687   "language_info": {
#     688    "codemirror_mode": {
#     689     "name": "ipython",
#     690     "version": 3
#     691    },
#     692    "file_extension": ".py",
#     693    "mimetype": "text/x-python",
#     694    "name": "python",
#     695    "nbconvert_exporter": "python",
#     696    "pygments_lexer": "ipython3",
#     697    "version": "3.10.10"
#     698   }
#     699  },
#     700  "nbformat": 4,
#     701  "nbformat_minor": 5
#     702 }
#
#     [... skipping hidden 12 frame]
#
# File /workspaces/ics-pa-sv/assignment/problem_2/lnn.ipynb:195, in kinetic_energy_fn(mass_matrix_nn_params, th, th_d)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "ac408b5e",
#       6    "metadata": {
#       7     "deletable": false,
#       8     "editable": false,
#       9     "nbgrader": {
#      10      "cell_type": "markdown",
#      11      "checksum": "a96d02d6346fa7399cf6da0111ce0937",
#      12      "grade": false,
#      13      "grade_id": "cell-b00828259c8e42e8",
#      14      "locked": true,
#      15      "schema_version": 3,
#      16      "solution": false,
#      17      "task": false
#      18     }
#      19    },
#      20    "source": [
#      21     "# RO47019: Intelligent Control Systems Practical Assignment\n",
#      22     "* Period: 2022-2023, Q3\n",
#      23     "* Course homepage: https://brightspace.tudelft.nl/d2l/home/500969\n",
#      24     "* Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)\n",
#      25     "* Teaching assistant: Ruben Martin Rodriguez (R.MartinRodriguez@student.tudelft.nl)\n",
#      26     "* (c) TU Delft, 2023\n",
#      27     "\n",
#      28     "Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:"
#      29    ]
#      30   },
#      31   {
#      32    "cell_type": "code",
#      33    "execution_count": null,
#      34    "id": "4f9e220c",
#      35    "metadata": {},
#      36    "outputs": [],
#      37    "source": [
#      38     "# Please fill in your names, student numbers, netID, and emails below.\n",
#      39     "STUDENT_1_NAME = \"Jasper Boogers\"\n",
#      40     "STUDENT_1_STUDENT_NUMBER = \"4591704\"\n",
#      41     "STUDENT_1_NETID = \"jboogers\"\n",
#      42     "STUDENT_1_EMAIL = \"j.m.boogers@student.tudelft.nl\""
#      43    ]
#      44   },
#      45   {
#      46    "cell_type": "code",
#      47    "execution_count": null,
#      48    "id": "8ba32571",
#      49    "metadata": {
#      50     "deletable": false,
#      51     "editable": false,
#      52     "nbgrader": {
#      53      "cell_type": "code",
#      54      "checksum": "042927213b84aa368aa3ea72caa4cb60",
#      55      "grade": true,
#      56      "grade_id": "cell-9f148ec62e0de49c",
#      57      "locked": true,
#      58      "points": 0,
#      59      "schema_version": 3,
#      60      "solution": false,
#      61      "task": false
#      62     }
#      63    },
#      64    "outputs": [],
#      65    "source": [
#      66     "# Note: this block is a check that you have filled in the above information.\n",
#      67     "# It will throw an AssertionError until all fields are filled\n",
#      68     "assert STUDENT_1_NAME != \"\"\n",
#      69     "assert STUDENT_1_STUDENT_NUMBER != \"\"\n",
#      70     "assert STUDENT_1_NETID != \"\"\n",
#      71     "assert STUDENT_1_EMAIL != \"\""
#      72    ]
#      73   },
#      74   {
#      75    "cell_type": "markdown",
#      76    "id": "af317a94",
#      77    "metadata": {
#      78     "deletable": false,
#      79     "editable": false,
#      80     "nbgrader": {
#      81      "cell_type": "markdown",
#      82      "checksum": "e76ef40fcc3f08a0484661497162a1a9",
#      83      "grade": false,
#      84      "grade_id": "cell-4ea391677951116c",
#      85      "locked": true,
#      86      "schema_version": 3,
#      87      "solution": false,
#      88      "task": false
#      89     }
#      90    },
#      91    "source": [
#      92     "### General announcements\n",
#      93     "\n",
#      94     "* Do *not* share your solutions, and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.\n",
#      95     "\n",
#      96     "* Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA.\n",
#      97     "\n",
#      98     "* There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.\n",
#      99     "\n",
#     100     "* This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook \"uneditable\" or \"unremovable\" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.\n",
#     101     "\n",
#     102     "* This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for youthat you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.\n",
#     103     "\n",
#     104     "Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\\rightarrow$Run All)."
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "code",
#     109    "execution_count": null,
#     110    "id": "3c956945",
#     111    "metadata": {},
#     112    "outputs": [],
#     113    "source": []
#     114   },
#     115   {
#     116    "cell_type": "markdown",
#     117    "id": "387d2c60",
#     118    "metadata": {
#     119     "deletable": false,
#     120     "editable": false,
#     121     "nbgrader": {
#     122      "cell_type": "markdown",
#     123      "checksum": "800a1848822df3ce5559209f09cb2494",
#     124      "grade": false,
#     125      "grade_id": "cell-ed88010142fb94bb",
#     126      "locked": true,
#     127      "schema_version": 3,
#     128      "solution": false,
#     129      "task": false
#     130     }
#     131    },
#     132    "source": [
#     133     "# Lagrangian Neural Network (LNN)\n",
#     134     "\n",
#     135     "**Author:** Maximilian Stölzle (M.W.Stolzle@tudelft.nl)\n",
#     136     "\n",
#     137     "This notebook will contain functions implement a Lagrangian neural network. Please follow the notebook `task_2c-2_lnn_implementation.ipynb`, which guides you through these implementations."
#     138    ]
#     139   },
#     140   {
#     141    "cell_type": "code",
#     142    "execution_count": 2,
#     143    "id": "c5a29eaa",
#     144    "metadata": {
#     145     "deletable": false,
#     146     "editable": false,
#     147     "nbgrader": {
#     148      "cell_type": "code",
#     149      "checksum": "a303d00318410d3b1621fc2d60bd9064",
#     150      "grade": false,
#     151      "grade_id": "cell-6d73deac900e51cb",
#     152      "locked": true,
#     153      "schema_version": 3,
#     154      "solution": false,
#     155      "task": false
#     156     }
#     157    },
#     158    "outputs": [],
#     159    "source": [
#     160     "from flax import linen as nn\n",
#     161     "from flax.core import FrozenDict\n",
#     162     "from functools import partial\n",
#     163     "from jax.config import config as jax_config\n",
#     164     "\n",
#     165     "jax_config.update(\"jax_platform_name\", \"cpu\")  # set default device to 'cpu'\n",
#     166     "jax_config.update(\"jax_enable_x64\", True)  # double precision\n",
#     167     "import jax\n",
#     168     "from jax import jit, debug\n",
#     169     "import jax.numpy as jnp\n",
#     170     "import numpy as np\n",
#     171     "from typing import Dict, Tuple\n",
#     172     "\n",
#     173     "from jax_double_pendulum.integrators import rk4_step\n",
#     174     "from jax_double_pendulum.utils import normalize_link_angles"
#     175    ]
#     176   },
#     177   {
#     178    "cell_type": "code",
#     179    "execution_count": null,
#     180    "id": "f23c573c",
#     181    "metadata": {
#     182     "deletable": false,
#     183     "nbgrader": {
#     184      "cell_type": "code",
#     185      "checksum": "e709fa40e5ce83f6c5c71bbe2754665d",
#     186      "grade": false,
#     187      "grade_id": "cell-90677efa4e583357",
#     188      "locked": false,
#     189      "schema_version": 3,
#     190      "solution": true,
#     191      "task": false
#     192     }
#     193    },
#     194    "outputs": [],
# --> 195    "source": [
#     196     "class MassMatrixNN(nn.Module):\n",
#     197     "    \"\"\"\n",
#     198     "    Neural network to approximate the mass matrix.\n",
#     199     "    \"\"\"\n",
#     200     "\n",
#     201     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     202     "\n",
#     203     "    diagonal_shift = 0.001  # shifting the diagonal before activation function\n",
#     204     "    diagonal_eps = 0.002  # small value added to the resulting diagonal\n",
#     205     "\n",
#     206     "    @nn.compact\n",
#     207     "    def __call__(self, th: jnp.ndarray) -> jnp.ndarray:\n",
#     208     "        \"\"\"\n",
#     209     "        Evaluate the mass matrix for the current neural network parameters\n",
#     210     "        Args:\n",
#     211     "            th: link angles of shape (2, ).\n",
#     212     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     213     "        Returns:\n",
#     214     "            M: mass matrix of shape (2, 2)\n",
#     215     "        \"\"\"\n",
#     216     "        num_dof = th.shape[-1]  # Degrees of Freedom of the robot\n",
#     217     "        num_nn_outputs = int((num_dof**2 + num_dof) / 2)\n",
#     218     "\n",
#     219     "        # implement the neural network layers\n",
#     220     "        # use nn.Dense and nn.softplus layers\n",
#     221     "        # the output of the last layer needs to be saved in the variable `m`\n",
#     222     "        # the elements of the triangular matrix are the outputs of the network\n",
#     223     "        m = nn.Dense(features=self.num_hidden)(th)\n",
#     224     "        m = nn.softplus(m)\n",
#     225     "        m = nn.Dense(features=self.num_hidden)(m)\n",
#     226     "        m = nn.softplus(m)\n",
#     227     "        m = nn.Dense(features=self.num_hidden)(m)\n",
#     228     "        m = nn.softplus(m)\n",
#     229     "        m = nn.Dense(features=self.num_hidden)(m)\n",
#     230     "        m = nn.softplus(m)\n",
#     231     "        m = nn.Dense(features=num_nn_outputs)(m)\n",
#     232     "\n",
#     233     "        # split-off the first num_dof as the diagonal entries\n",
#     234     "        l_diagonal, l_off_diagonal = jnp.split(\n",
#     235     "            m,\n",
#     236     "            np.array(\n",
#     237     "                [\n",
#     238     "                    num_dof,\n",
#     239     "                ]\n",
#     240     "            ),\n",
#     241     "            axis=-1,\n",
#     242     "        )\n",
#     243     "\n",
#     244     "        # ensure positive diagonal\n",
#     245     "        # first, add `self.diagonal_shift` to the diagonal\n",
#     246     "        # then, apply softplus\n",
#     247     "        # finally, add `self.diagonal_eps` to the diagonal\n",
#     248     "        # YOUR CODE HERE\n",
#     249     "        l_diagonal = l_diagonal.at[:].set(l_diagonal+self.diagonal_shift)\n",
#     250     "        l_diagonal = nn.softplus(l_diagonal)\n",
#     251     "        l_diagonal = l_diagonal.at[:].set(l_diagonal+self.diagonal_eps)\n",
#     252     "\n",
#     253     "        # Calculate the indices of the diagonal elements of L:\n",
#     254     "        indices_diag = np.arange(num_dof, dtype=int) + 1\n",
#     255     "        indices_diag = (indices_diag * (indices_diag + 1) / 2 - 1).astype(int)  # [0, 2]\n",
#     256     "        # Calculate the indices of the off-diagonal elements of L:\n",
#     257     "        indices_off_diag = np.setdiff1d(np.arange(num_nn_outputs), indices_diag)  # [1]\n",
#     258     "        # Indexing for concatenation of l_diagonal and l_off_diagonal\n",
#     259     "        indices_nn_output = np.hstack((indices_diag, indices_off_diag))  # [0, 2, 1]\n",
#     260     "\n",
#     261     "        # vector of lower triangular matrix (i.e. flattened lower triangular matrix)\n",
#     262     "        vec_tril = jnp.concatenate([l_diagonal, l_off_diagonal], axis=-1)[\n",
#     263     "            ..., indices_nn_output\n",
#     264     "        ]\n",
#     265     "\n",
#     266     "        # construct empty triangular matrix\n",
#     267     "        tril_mat = jnp.zeros((num_dof, num_dof))\n",
#     268     "        # (i, j) indices of lower triangular matrix\n",
#     269     "        indices_tril = np.tril_indices(num_dof)  # (array([0, 1, 1]), array([0, 0, 1]))\n",
#     270     "        # populate triangular matrix from vector\n",
#     271     "        tril_mat = tril_mat.at[indices_tril].set(vec_tril[:])\n",
#     272     "\n",
#     273     "        # construct mass matrix from triangular matrix\n",
#     274     "        M = tril_mat @ tril_mat.transpose()\n",
#     275     "\n",
#     276     "        return M"
#     277    ]
#     278   },
#     279   {
#     280    "cell_type": "code",
#     281    "execution_count": null,
#     282    "id": "a6974402",
#     283    "metadata": {
#     284     "deletable": false,
#     285     "nbgrader": {
#     286      "cell_type": "code",
#     287      "checksum": "54d2a75f25cd3fc260bc1c2a7370fdfc",
#     288      "grade": false,
#     289      "grade_id": "cell-e2583bbbc2ae1715",
#     290      "locked": false,
#     291      "schema_version": 3,
#     292      "solution": true,
#     293      "task": false
#     294     }
#     295    },
#     296    "outputs": [],
#     297    "source": [
#     298     "class PotentialEnergyNN(nn.Module):\n",
#     299     "    \"\"\"\n",
#     300     "    Neural network to approximate the potential energy.\n",
#     301     "    \"\"\"\n",
#     302     "\n",
#     303     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     304     "\n",
#     305     "    @nn.compact\n",
#     306     "    def __call__(self, th: jnp.ndarray) -> jnp.ndarray:\n",
#     307     "        \"\"\"\n",
#     308     "        Evaluate the potential energy for the current neural network parameters\n",
#     309     "        Args:\n",
#     310     "            th: link angles of shape (2, ).\n",
#     311     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     312     "        Returns:\n",
# ...
#     372    "execution_count": null,
#     373    "id": "09e7875a",
#     374    "metadata": {
#     375     "deletable": false,
#     376     "nbgrader": {
#     377      "cell_type": "code",
#     378      "checksum": "6c2fa7ba4d25a8bf0165658284855273",
#     379      "grade": false,
#     380      "grade_id": "cell-6a3a2cc1abe3951d",
#     381      "locked": false,
#     382      "schema_version": 3,
#     383      "solution": true,
#     384      "task": false
#     385     }
#     386    },
#     387    "outputs": [],
#     388    "source": [
#     389     "@jit\n",
#     390     "def potential_energy_fn(\n",
#     391     "    potential_energy_nn_params: FrozenDict, th: jnp.ndarray\n",
#     392     ") -> jnp.ndarray:\n",
#     393     "    \"\"\"\n",
#     394     "    Compute the potential energy of the system using the `PotentialEnergyNN` neural network\n",
#     395     "    Args:\n",
#     396     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     397     "        th: link angles of shape (2, ).\n",
#     398     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     399     "    Returns:\n",
#     400     "        U: potential energy of shape ( )\n",
#     401     "    \"\"\"\n",
#     402     "    # evaluate the `PotentialEnergyNN` at current system state\n",
#     403     "    U = PotentialEnergyNN().apply(potential_energy_nn_params, th)\n",
#     404     "\n",
#     405     "    return U.squeeze()"
#     406    ]
#     407   },
#     408   {
#     409    "cell_type": "code",
#     410    "execution_count": null,
#     411    "id": "6126ac5a",
#     412    "metadata": {
#     413     "deletable": false,
#     414     "nbgrader": {
#     415      "cell_type": "code",
#     416      "checksum": "e5cf488189981146c3cc1464eaf904ef",
#     417      "grade": false,
#     418      "grade_id": "cell-216db944065f69db",
#     419      "locked": false,
#     420      "schema_version": 3,
#     421      "solution": true,
#     422      "task": false
#     423     }
#     424    },
#     425    "outputs": [],
#     426    "source": [
#     427     "@jit\n",
#     428     "def lagrangian_fn(\n",
#     429     "    mass_matrix_nn_params: FrozenDict,\n",
#     430     "    potential_energy_nn_params: FrozenDict,\n",
#     431     "    th: jnp.ndarray,\n",
#     432     "    th_d: jnp.ndarray,\n",
#     433     ") -> jnp.ndarray:\n",
#     434     "    \"\"\"\n",
#     435     "    Compute the Lagrangian of the system using a learned neural-network-based mass matrix and potential energy\n",
#     436     "    Args:\n",
#     437     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     438     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     439     "        th: link angles of shape (2, ).\n",
#     440     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     441     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     442     "    Returns:\n",
#     443     "        L: Lagrangian of shape ( )\n",
#     444     "    \"\"\"\n",
#     445     "    # Compute the Lagrangian\n",
#     446     "    T = kinetic_energy_fn(mass_matrix_nn_params, th, th_d)\n",
#     447     "    U = potential_energy_fn(potential_energy_nn_params, th)\n",
#     448     "\n",
#     449     "    return T-U"
#     450    ]
#     451   },
#     452   {
#     453    "cell_type": "code",
#     454    "execution_count": null,
#     455    "id": "6b4ced74",
#     456    "metadata": {
#     457     "deletable": false,
#     458     "nbgrader": {
#     459      "cell_type": "code",
#     460      "checksum": "f16ac3536395e5a99f76df9fe88d2ef1",
#     461      "grade": false,
#     462      "grade_id": "cell-82a33f0bd7f4ddcc",
#     463      "locked": false,
#     464      "schema_version": 3,
#     465      "solution": true,
#     466      "task": false
#     467     }
#     468    },
#     469    "outputs": [],
#     470    "source": [
#     471     "@jit\n",
#     472     "def dynamical_matrices(\n",
#     473     "    mass_matrix_nn_params: FrozenDict,\n",
#     474     "    potential_energy_nn_params: FrozenDict,\n",
#     475     "    th: jnp.ndarray,\n",
#     476     "    th_d: jnp.ndarray,\n",
#     477     ") -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray]:\n",
#     478     "    \"\"\"\n",
#     479     "    Compute the dynamical matrices of the system using a learned neural-network-based\n",
#     480     "    mass matrix and potential energy\n",
#     481     "    The resulting Equations of Motion (EoM) are given by:\n",
#     482     "        M @ th_dd + C @ th_d + G = tau\n",
#     483     "    where tau are the external torques applied on the links.\n",
#     484     "\n",
#     485     "    Args:\n",
#     486     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     487     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     488     "        th: link angles of double pendulum of shape (2, )\n",
#     489     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     490     "\n",
#     491     "    Returns:\n",
#     492     "        M: mass matrix of shape (2, 2)\n",
#     493     "        C: coriolis and centrifugal matrix of shape (2, 2)\n",
#     494     "        G: gravity matrix of shape (2, )\n",
#     495     "    \"\"\"\n",
#     496     "    # the neural network needs to be robust to the redundancy of th = th + n * 2*pi\n",
#     497     "    # therefore, we first project the given link angles onto the interval [-pi, pi]\n",
#     498     "    # Hint: use the `jax_double_pendulum.utils.normalize_link_angles` function.\n",
#     499     "    # Hint: use `jax.grad` or `jax.value_and_grad` for the 1st-order partial derivatives\n",
#     500     "    # Hint: use the `jax.hessian` function for computing the 2nd-order partial derivatives.\n",
#     501     "    # YOUR CODE HERE\n",
#     502     "    th = normalize_link_angles(th)\n",
#     503     "\n",
#     504     "    # Compute the dynamical matrices by taking the appropiate partial derivatives of the Lagrangian\n",
#     505     "    \n",
#     506     "    # M, C, G = jnp.zeros((2, 2)), jnp.zeros((2, 2)), jnp.zeros((2,))\n",
#     507     "    # # YOUR CODE HERE\n",
#     508     "    # raise NotImplementedError()\n",
#     509     "\n",
#     510     "    lag = partial(lagrangian_fn, mass_matrix_nn_params, potential_energy_nn_params)\n",
#     511     "    _, (C, M) = jax.hessian(lag,(0,1))(th, th_d)\n",
#     512     "    G = jax.grad(lag, 0)(th, th_d)\n",
#     513     "    return M, C, -G"
#     514    ]
#     515   },
#     516   {
#     517    "cell_type": "code",
#     518    "execution_count": null,
#     519    "id": "05b32d77",
#     520    "metadata": {
#     521     "deletable": false,
#     522     "nbgrader": {
#     523      "cell_type": "code",
#     524      "checksum": "d976761dc16911853cf1cacfdc81d533",
#     525      "grade": false,
#     526      "grade_id": "cell-2538b9eeb0fe06f9",
#     527      "locked": false,
#     528      "schema_version": 3,
#     529      "solution": true,
#     530      "task": false
#     531     }
#     532    },
#     533    "outputs": [],
#     534    "source": [
#     535     "@jit\n",
#     536     "def continuous_forward_dynamics(\n",
#     537     "    mass_matrix_nn_params: FrozenDict,\n",
#     538     "    potential_energy_nn_params: FrozenDict,\n",
#     539     "    th: jnp.ndarray,\n",
#     540     "    th_d: jnp.ndarray,\n",
#     541     "    tau: jnp.ndarray = jnp.zeros((2,)),\n",
#     542     ") -> jnp.ndarray:\n",
#     543     "    \"\"\"\n",
#     544     "    Compute the continuous forward dynamics of the system using a learned neural-network-based\n",
#     545     "    mass matrix and potential energy\n",
#     546     "    Args:\n",
#     547     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     548     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     549     "        th: link angles of double pendulum of shape (2, )\n",
#     550     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     551     "        tau: link torques of double pendulum of shape (2, )\n",
#     552     "    Returns:\n",
#     553     "        th_dd: link angular accelerations of double pendulum of shape (2, )\n",
#     554     "    \"\"\"\n",
#     555     "    # Compute the angular acceleration of the links\n",
#     556     "    th_dd = jnp.zeros((2,))\n",
#     557     "    # YOUR CODE HERE\n",
#     558     "    M, C, G = dynamical_matrices(mass_matrix_nn_params,\n",
#     559     "                                potential_energy_nn_params,\n",
#     560     "                                th,\n",
#     561     "                                th_d)\n",
#     562     "    th_dd = jnp.linalg.inv(M) @ (tau - C @ th_d - G)\n",
#     563     "\n",
#     564     "    return th_dd"
#     565    ]
#     566   },
#     567   {
#     568    "cell_type": "code",
#     569    "execution_count": null,
#     570    "id": "c6819b64",
#     571    "metadata": {
#     572     "deletable": false,
#     573     "nbgrader": {
#     574      "cell_type": "code",
#     575      "checksum": "e00d6698af6c0747d29a5de335b9d088",
#     576      "grade": false,
#     577      "grade_id": "cell-04d5fab5a1e9a1e6",
#     578      "locked": false,
#     579      "schema_version": 3,
#     580      "solution": true,
#     581      "task": false
#     582     }
#     583    },
#     584    "outputs": [],
#     585    "source": [
#     586     "def continuous_state_space_dynamics(\n",
#     587     "    mass_matrix_nn_params: FrozenDict,\n",
#     588     "    potential_energy_nn_params: FrozenDict,\n",
#     589     "    x: jnp.ndarray,\n",
#     590     "    tau: jnp.ndarray,\n",
#     591     ") -> Tuple[jnp.ndarray, jnp.ndarray]:\n",
#     592     "    \"\"\"\n",
#     593     "    Compute the continuous forward dynamics of the system in state-space representation\n",
#     594     "    using the Lagrangian neural network\n",
#     595     "    Args:\n",
#     596     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     597     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     598     "        x: system state of shape (4, ) consisting of the link angles and velocities\n",
#     599     "        tau: link torques of shape (2, )\n",
#     600     "    Returns:\n",
#     601     "        dx_dt: time derivative of the system state of shape (4, )\n",
#     602     "        y: system output of shape (2, ) consisting of the link angles\n",
#     603     "    \"\"\"\n",
#     604     "    # YOUR CODE HERE\n",
#     605     "    th, th_d = jnp.split(x, 2)\n",
#     606     "    th_dd = continuous_forward_dynamics(mass_matrix_nn_params, potential_energy_nn_params, th, th_d, tau)\n",
#     607     "\n",
#     608     "    dx_dt = jnp.concatenate([th_d, th_dd])\n",
#     609     "    y = th\n",
#     610     "    return dx_dt, y"
#     611    ]
#     612   },
#     613   {
#     614    "cell_type": "code",
#     615    "execution_count": null,
#     616    "id": "92563f5d",
#     617    "metadata": {
#     618     "deletable": false,
#     619     "nbgrader": {
#     620      "cell_type": "code",
#     621      "checksum": "0d5de7eb08c349b525f028391bfdcf32",
#     622      "grade": false,
#     623      "grade_id": "cell-9290e00886679359",
#     624      "locked": false,
#     625      "schema_version": 3,
#     626      "solution": true,
#     627      "task": false
#     628     }
#     629    },
#     630    "outputs": [],
#     631    "source": [
#     632     "@jit\n",
#     633     "def discrete_forward_dynamics(\n",
#     634     "    mass_matrix_nn_params: FrozenDict,\n",
#     635     "    potential_energy_nn_params: FrozenDict,\n",
#     636     "    dt: jnp.ndarray,\n",
#     637     "    th_curr: jnp.ndarray,\n",
#     638     "    th_d_curr: jnp.ndarray,\n",
#     639     "    tau: jnp.ndarray = jnp.zeros((2,)),\n",
#     640     ") -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray]:\n",
#     641     "    \"\"\"\n",
#     642     "    Compute the discrete forward dynamics of the system using a learned neural-network-based\n",
#     643     "    mass matrix and potential energy\n",
#     644     "    Args:\n",
#     645     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     646     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     647     "        dt: time step between the current and the next state [s] of shape ( )\n",
#     648     "        th_curr: current link angles of double pendulum of shape (2, )\n",
#     649     "        th_d_curr: current link angular velocities of double pendulum of shape (2, )\n",
#     650     "        tau: link torques of double pendulum of shape (2, )\n",
#     651     "    Returns:\n",
#     652     "        th_next: link angles at the next time step of double pendulum of shape (2, )\n",
#     653     "        th_d_next: link angular velocities at the next time step of double pendulum of shape (2, )\n",
#     654     "        th_dd: link angular accelerations between current and next time step of double pendulum of shape (2, )\n",
#     655     "    \"\"\"\n",
#     656     "    # YOUR CODE HERE\n",
#     657     "    th_dd = continuous_forward_dynamics(mass_matrix_nn_params, potential_energy_nn_params, th_curr, th_d_curr, tau)\n",
#     658     "    x_next = rk4_step(\n",
#     659     "        ode_fun= lambda _x: partial(continuous_state_space_dynamics,\n",
#     660     "                                    mass_matrix_nn_params,\n",
#     661     "                                    potential_energy_nn_params,\n",
#     662     "                                    tau=tau)(_x)[0],\n",
#     663     "        x=jnp.concatenate([th_curr, th_d_curr]),\n",
#     664     "        dt=dt\n",
#     665     "    )\n",
#     666     "\n",
#     667     "    th_next, th_d_next = jnp.split(x_next, 2)\n",
#     668     "\n",
#     669     "    return th_next, th_d_next, th_dd"
#     670    ]
#     671   },
#     672   {
#     673    "cell_type": "code",
#     674    "execution_count": null,
#     675    "id": "7cdbdacd",
#     676    "metadata": {},
#     677    "outputs": [],
#     678    "source": []
#     679   }
#     680  ],
#     681  "metadata": {
#     682   "kernelspec": {
#     683    "display_name": "Python 3 (ipykernel)",
#     684    "language": "python",
#     685    "name": "python3"
#     686   },
#     687   "language_info": {
#     688    "codemirror_mode": {
#     689     "name": "ipython",
#     690     "version": 3
#     691    },
#     692    "file_extension": ".py",
#     693    "mimetype": "text/x-python",
#     694    "name": "python",
#     695    "nbconvert_exporter": "python",
#     696    "pygments_lexer": "ipython3",
#     697    "version": "3.10.10"
#     698   }
#     699  },
#     700  "nbformat": 4,
#     701  "nbformat_minor": 5
#     702 }
#
#     [... skipping hidden 2 frame]
#
# File ~/.local/lib/python3.10/site-packages/flax/linen/linear.py:196, in Dense.__call__(self, inputs)
#     186 @compact
#     187 def __call__(self, inputs: Array) -> Array:
#     188   """Applies a linear transformation to the inputs along the last dimension.
#     189
#     190   Args:
#    (...)
#     194     The transformed input.
#     195   """
# --> 196   kernel = self.param('kernel',
#     197                       self.kernel_init,
#     198                       (jnp.shape(inputs)[-1], self.features),
#     199                       self.param_dtype)
#     200   if self.use_bias:
#     201     bias = self.param('bias', self.bias_init, (self.features,),
#     202                       self.param_dtype)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/flax/core/scope.py:840, in Scope.param(self, name, init_fn, unbox, *init_args)
#     838 if not self.is_mutable_collection('params'):
#     839   if self.is_collection_empty('params'):
# --> 840     raise errors.ScopeCollectionNotFound('params', name, self.path_text)
#     841   raise errors.ScopeParamNotFoundError(name, self.path_text)
#     842 value = init_fn(self.make_rng('params'), *init_args)
#
# ScopeCollectionNotFound: Tried to access "kernel" from collection "params" in "/Dense_0" but the collection is empty. (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.ScopeCollectionNotFound)

# %% [markdown]
# ## Continuous forward dynamics (4p)
#
# Next, please take the various partial derivatives of the Lagrangian to compute the dynamical matrices (i.e. the components of the equations of motion) in the function `dynamical_matrices`
#
# \begin{equation}
#     M = \frac{\partial^2 \mathcal{L}}{\partial \dot{\theta}^2},
#     \qquad
#     C = \frac{\partial^2 \mathcal{L}}{\partial \theta \partial \dot{\theta}},
#     \qquad
#     G = - \frac{\partial \mathcal{L}}{\partial \theta}.
# \end{equation}
#
# Make sure that before you evaluate the Lagrangian, you normalize the link angles $\theta$ to the interval $[-\pi, \pi]$. If we were not to implement this normalization, we would (likely) get a different behaviour for $\theta = a$ or $\theta = a + 2 \: \pi$, which is not desired. This would also drastically increase the amount of training data we would require.
#
# Then, please compute the continuous forward dynamics (i.e. determining $\ddot{\theta}$ for a given state $(\theta, \dot{\theta})$ and input $\tau$) in the function `continuous_forward_dynamics`. For this implementation, you can take inspiration from the analytical solution in `jax_double_pendulum.dynamics.continuous_forward_dynamics`.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import dynamical_matrices from lnn.ipynb
from ipynb.fs.full.lnn import dynamical_matrices, continuous_forward_dynamics

_M, _C, _G = dynamical_matrices(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _th,
    _th_d,
)

print("Computed M:\n", _M)
print("Computed C:\n", _C)
print("Computed G:\n", _G)

# zero applied torque
_tau = jnp.ones((2,))

_th_dd = continuous_forward_dynamics(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _th,
    _th_d,
    _tau,
)

print("Computed th_dd:\n", _th_dd)

# the mass matrix estimated by the neural network should be the same as d2L_d2thd
assert jnp.allclose(_M_nn, _M)
# Out:
# Computed M:
#  [[ 0.54595144 -0.53372961]
#  [-0.53372961  0.97476694]]
# Computed C:
#  [[ 0.25423738  0.00539128]
#  [-0.069986    0.09831604]]
# Computed G:
#  [-0.24982781 -0.21771264]
# Computed th_dd:
#  [4.14726048 3.42874464]

# %% [markdown]
# ## State-space dynamics (1p)
#
# Please implement dynamics in a nonlinear state-space representation into the function `continuous_state_space_dynamics`. The state-space representation needs to have the following structure
#
# \begin{equation}
#     \frac{\mathrm{d}x}{\mathrm{d}t} = f(x, \tau),\\
#     y = g(x, \tau),
# \end{equation}
#
# where $x \in \mathbb{R}^4$ is the state of the system. For implementing this function, you can take inspiration from `jax_double_pendulum.dynamics.continuous_state_space_dynamics`.
#
# Having the EoM in this structure will allow us in the next step to use standard methods such as [RK4](https://en.wikipedia.org/wiki/Runge–Kutta_methods) to integrate the ODE in time.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import continuous_state_space_dynamics from lnn.ipynb
from ipynb.fs.full.lnn import continuous_state_space_dynamics

# define a dummy state
_x = jnp.concatenate([_th, _th_d])

_dx_dt, _y = continuous_state_space_dynamics(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _x,
    _tau,
)

print("Time derivative of the state\n", _dx_dt)
print("System output", _y)
# Out:
# Time derivative of the state
#  [3.14159265 3.14159265 4.14726048 3.42874464]
# System output [0. 0.]

# %% [markdown]
# ## Discrete-time forward dynamics (1p)
#
# Now, we move on to implementing the discrete-time forward dynamics into `discrete_forward_dynamics`.
# Please use the `jax_double_pendulum.integrators.rk4_step` function to integrate the continuous state-space dynamics for one time-step of duration `dt`. The `rk4_step` expects as its first argument an `ode_fun`, which needs to conform to the following syntax: `rk4_step(x) -> dx_dt` (i.e. a mapping from the state $x$ to its time-derivative $\dot{x}$). For implementing this function, you can take inspiration from `jax_double_pendulum.dynamics.discrete_forward_dynamics`.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import discrete_forward_dynamics from lnn.ipynb
from ipynb.fs.full.lnn import discrete_forward_dynamics

_dt = 1e-2  # time-step [s]
_th_next, _th_d_next, _th_dd = discrete_forward_dynamics(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _dt,
    _th,
    _th_d,
    _tau,
)

print("Computed next link angles:", _th_next)
print("Computed next link angular velocities:", _th_d_next)
print("Computed angular link accelerations:", _th_dd)
# Out:
# Computed next link angles: [0.03162163 0.0315865 ]
# Computed next link angular velocities: [3.18256705 3.17561977]
# Computed angular link accelerations: [4.14726048 3.42874464]
